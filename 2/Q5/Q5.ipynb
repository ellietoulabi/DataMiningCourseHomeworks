# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## a)

# %%
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('correctedDiabetes.csv')
imp = SimpleImputer(strategy='mean')
imp.fit(df)
x=pd.DataFrame(imp.transform(df),  columns=['Pregnancies','Glucose','BloodPressure','SkinThickness',
                                            'Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome'])

df.update(x)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6.0    148.0           72.0      35.000000  163.513514  33.6
# 1            1.0     85.0           66.0      29.000000  163.513514  26.6
# 2            8.0    183.0           64.0      28.904494  163.513514  23.3
# 3            1.0     89.0           66.0      23.000000   94.000000  28.1
# 4            0.0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 497          2.0     81.0           72.0      15.000000   76.000000  30.1
# 498          7.0    195.0           70.0      33.000000  145.000000  25.1
# 499          6.0    154.0           74.0      32.000000  193.000000  29.3
# 500          2.0    117.0           90.0      19.000000   71.000000  25.2
# 501          3.0     84.0           72.0      32.000000  163.513514  37.2
#
#      DiabetesPedigreeFunction   Age  Outcome
# ...

# %% [markdown]
# ## b)
#
# #### IQR

# %%
# IQR Outlier

Q1 = df.quantile(0.25) 
Q3 = df.quantile(0.75) 
IQR = Q3 - Q1  
mask = (df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))

pd.set_option('display.max_rows', df.shape[0]+1)

df[mask]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            NaN      NaN            NaN            NaN      NaN   NaN
# 1            NaN      NaN            NaN            NaN      NaN   NaN
# 2            NaN      NaN            NaN            NaN      NaN   NaN
# 3            NaN      NaN            NaN            NaN      NaN   NaN
# 4            NaN      NaN            NaN            NaN      NaN   NaN
# 5            NaN      NaN            NaN            NaN      NaN   NaN
# 6            NaN      NaN            NaN            NaN      NaN   NaN
# 7            NaN      NaN            NaN            NaN      NaN   NaN
# 8            NaN      NaN            NaN           45.0    543.0   NaN
# 9            NaN      NaN            NaN            NaN      NaN   NaN
# 10           NaN      NaN            NaN            NaN      NaN   NaN
# 11           NaN      NaN            NaN            NaN      NaN   NaN
# ...

# %%
boxplot = df.boxplot(figsize=(20,20),column=['Pregnancies','Glucose','BloodPressure','SkinThickness',
                                            'Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome'])

# %% [markdown]
# ### Pregnancies

# %%
df.boxplot(column=['Pregnancies'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['Pregnancies'].notna()]['Pregnancies'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# 88     15.0
# 159    17.0
# 298    14.0
# 455    14.0
# Name: Pregnancies, dtype: float64

# %% [markdown]
# ### Glucose

# %%
df.boxplot(column=['Glucose'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['Glucose'].notna()]['Glucose'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# 374    300.0
# 384     12.0
# 386    250.0
# 402    800.0
# Name: Glucose, dtype: float64

# %% [markdown]
# ### BloodPressure

# %%
df.boxplot(column=['BloodPressure'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['BloodPressure'].notna()]['BloodPressure'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# 18      30.0
# 43     110.0
# 84     108.0
# 106    122.0
# 125     30.0
# 177    110.0
# 362    108.0
# Name: BloodPressure, dtype: float64

# %% [markdown]
# ### SkinThickness

# %%
df.boxplot(column=['SkinThickness'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['SkinThickness'].notna()]['SkinThickness'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# 8      45.0
# 16     47.0
# 32     11.0
# 39     47.0
# 50     11.0
# 55     10.0
# 57     60.0
# 68     13.0
# 80     13.0
# 86     54.0
# 99     51.0
# 120    56.0
# 130    14.0
# 134    13.0
# 150    50.0
# 155    44.0
# 169    12.0
# 177    46.0
# 191    44.0
# 197    13.0
# 198    44.0
# 211    54.0
# 254     7.0
# 273    50.0
# 275    52.0
# 279    10.0
# 286    44.0
# 289    43.0
# 293    45.0
# 307    14.0
# 313    10.0
# 316    11.0
# 320    12.0
# 335    43.0
# 340    13.0
# 353    12.0
# 370    48.0
# 374    43.0
# 375    43.0
# 382     8.0
# 385    13.0
# 392    14.0
# 393    12.0
# 409    49.0
# 428    46.0
# 432    11.0
# 434     8.0
# 444    12.0
# 445    63.0
# 446    12.0
# 447    45.0
# 450    13.0
# 458    48.0
# 465    13.0
# 466    10.0
# 476    45.0
# Name: SkinThickness, dtype: float64

# %%
### Insulin

# %%
df.boxplot(column=['Insulin'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['Insulin'].notna()]['Insulin'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# 8      543.0
# 13     846.0
# 16     230.0
# 20     235.0
# 31     245.0
# 43     240.0
# 51      36.0
# 52      23.0
# 53     300.0
# 54     342.0
# 56     304.0
# 68      38.0
# 73     270.0
# 92      48.0
# 103     40.0
# 108     18.0
# 109     36.0
# 111    495.0
# 112     37.0
# 119     51.0
# 134     49.0
# 136     50.0
# 139    325.0
# 144    284.0
# 153    485.0
# 162    285.0
# 173     48.0
# 182     23.0
# 186    495.0
# 197     48.0
# 199    318.0
# 203     44.0
# 206    280.0
# 215    271.0
# 220    478.0
# 225     32.0
# 228    744.0
# 231    370.0
# 232     37.0
# 234     45.0
# 247    680.0
# 248    402.0
# 254    258.0
# 258    375.0
# 273     45.0
# 279    278.0
# 286    545.0
# 288     49.0
# 290     40.0
# 296    360.0
# 302     42.0
# 320    231.0
# 323     29.0
# 331     52.0
# 335    255.0
# 353     43.0
# 359    249.0
# 360    325.0
# 364    293.0
# 370    465.0
# 375    325.0
# 385     50.0
# 388    285.0
# 392    415.0
# ...

# %%
### BMI

# %%
df.boxplot(column=['BMI'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['BMI'].notna()]['BMI'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# 120    53.2
# 125    55.0
# 177    67.1
# 193    52.3
# 247    52.3
# 303    52.9
# 445    59.4
# Name: BMI, dtype: float64

# %% [markdown]
# ### DiabetesPedigreeFunction

# %%
df.boxplot(column=['DiabetesPedigreeFunction'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['DiabetesPedigreeFunction'].notna()]['DiabetesPedigreeFunction'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# 4      2.288
# 12     1.441
# 39     1.390
# 45     1.893
# 58     1.781
# 100    1.222
# 147    1.400
# 187    1.321
# 218    1.224
# 228    2.329
# 243    1.318
# 245    1.213
# 259    1.353
# 292    1.224
# 308    1.391
# 330    1.476
# 370    2.137
# 371    1.731
# 383    1.268
# 395    1.600
# 445    2.420
# Name: DiabetesPedigreeFunction, dtype: float64

# %% [markdown]
# ### Age

# %%
df.boxplot(column=['Age'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['Age'].notna()]['Age'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# 123    69.0
# 129    62.0
# 148    65.0
# 221    66.0
# 263    63.0
# 294    65.0
# 361    63.0
# 362    65.0
# 363    67.0
# 390    99.0
# 403     1.0
# 453    72.0
# 456    62.0
# 459    81.0
# 479    63.0
# 489    67.0
# 495    66.0
# Name: Age, dtype: float64

# %%
### Outcome

# %%
df.boxplot(column=['Outcome'])
print("OUTLIARS:\n(INDEX  VALUE) ")
df[mask].loc[df['Outcome'].notna()]['Outcome'].dropna()
# Out:
# OUTLIARS:
# (INDEX  VALUE)
# Series([], Name: Outcome, dtype: float64)

# %%
### REMOVE OUTLIERs

# %%
print("#Outliers = ",df.shape[0]-df[~mask].dropna().shape[0])
print("#Not outliers = ",df[~mask].dropna().shape[0])
df[~mask].dropna().head(10)
# Out:
# #Outliers =  164
# #Not outliers =  338
#     Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin       BMI  \
# 0           6.0    148.0      72.000000      35.000000  163.513514  33.60000
# 1           1.0     85.0      66.000000      29.000000  163.513514  26.60000
# 2           8.0    183.0      64.000000      28.904494  163.513514  23.30000
# 3           1.0     89.0      66.000000      23.000000   94.000000  28.10000
# 5           5.0    116.0      74.000000      28.904494  163.513514  25.60000
# 6           3.0     78.0      50.000000      32.000000   88.000000  31.00000
# 7          10.0    115.0      72.264706      28.904494  163.513514  35.30000
# 9           8.0    125.0      96.000000      28.904494  163.513514  32.50752
# 10          4.0    110.0      92.000000      28.904494  163.513514  37.60000
# 11         10.0    168.0      74.000000      28.904494  163.513514  38.00000
#
#     DiabetesPedigreeFunction   Age  Outcome
# ...

# %% [markdown]
# ### c)

# %%
from scipy import stats

# %%
Z_Scored = pd.DataFrame(stats.zscore(df),columns=['Pregnancies','Glucose','BloodPressure','SkinThickness',
                                            'Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome'])
z_mask = (Z_Scored>3) | (Z_Scored<-3)


print("#Outliers = ",df.shape[0]-df[~z_mask].dropna().shape[0])
print("#Not outliers = ",df[~z_mask].dropna().shape[0])
df[~z_mask].dropna().head(10)
# Out:
# #Outliers =  40
# #Not outliers =  462
#     Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin       BMI  \
# 0           6.0    148.0      72.000000      35.000000  163.513514  33.60000
# 1           1.0     85.0      66.000000      29.000000  163.513514  26.60000
# 2           8.0    183.0      64.000000      28.904494  163.513514  23.30000
# 3           1.0     89.0      66.000000      23.000000   94.000000  28.10000
# 5           5.0    116.0      74.000000      28.904494  163.513514  25.60000
# 6           3.0     78.0      50.000000      32.000000   88.000000  31.00000
# 7          10.0    115.0      72.264706      28.904494  163.513514  35.30000
# 9           8.0    125.0      96.000000      28.904494  163.513514  32.50752
# 10          4.0    110.0      92.000000      28.904494  163.513514  37.60000
# 11         10.0    168.0      74.000000      28.904494  163.513514  38.00000
#
#     DiabetesPedigreeFunction   Age  Outcome
# ...
